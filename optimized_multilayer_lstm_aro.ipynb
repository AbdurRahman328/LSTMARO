# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
plt.style.use('ggplot')

import tensorflow as tf
# %load_ext tensorboard

import warnings
warnings.filterwarnings('ignore')

import os
import datetime as dt
# Out:
# WARNING:tensorflow:From C:\Users\abdur\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Dataset is stored in Drive and link to drive is /content/drive/MyDrive/FinalProject/Datasets/gspc_final.csv

# %%
data = pd.read_csv("D:\Final Year Project\Dataset\Proposed Paper Dataset\S&P 500\gspc_high_low.csv")

# %%
data.head()
# Out:
#          Date         Open         High          Low        Close         SAR  \
# 0  03-01-2006  1248.290039  1270.219971  1245.739990  1268.800049         NaN
# 1  04-01-2006  1268.800049  1275.369995  1267.739990  1273.459961  1245.73999
# 2  05-01-2006  1273.459961  1276.910034  1270.300049  1273.479980  1245.73999
# 3  06-01-2006  1273.479980  1286.089966  1273.479980  1285.449951  1245.73999
# 4  09-01-2006  1285.449951  1290.780029  1284.819946  1290.150024  1245.73999
#
#        MACD  RSI  ATR  MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# 0  0.000000  NaN  NaN  NaN  89.839996  11.14  4.34     4.7     91.2
# 1  0.196947  NaN  NaN  NaN  89.139999  11.37  4.22     4.7     91.2
# 2  0.371553  NaN  NaN  NaN  89.330002  11.31  4.24     4.7     91.2
# 3  1.030907  NaN  NaN  NaN  88.849998  11.00  4.22     4.7     91.2
# 4  1.810155  NaN  NaN  NaN  89.250000  11.13  4.25     4.7     91.2

# %%
data.isna().sum()
# Out:
# Date        0
# Open        0
# High        0
# Low         0
# Close       0
# SAR         1
# MACD        0
# RSI         8
# ATR        49
# MFI        29
# USDX        2
# VIX         0
# EFFR       35
# UNRATE      0
# UMSCENT     0
# dtype: int64

# %%
data.drop(data.index[:49], inplace=True)
data.reset_index(drop=True, inplace=True)
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')
data['Date'] = data['Date'].dt.strftime('%Y-%m-%d')
data.set_index("Date",inplace=True)
data.head()
# Out:
#                    Open         High          Low        Close         SAR  \
# Date
# 2006-03-15  1297.479980  1304.400024  1294.969971  1303.020020  1245.73999
# 2006-03-16  1303.020020  1310.449951  1303.020020  1305.329956  1245.73999
# 2006-03-17  1305.329956  1309.790039  1305.319946  1307.250000  1245.73999
# 2006-03-20  1307.250000  1310.000000  1303.589966  1305.079956  1245.73999
# 2006-03-21  1305.079956  1310.880005  1295.819946  1297.229980  1245.73999
#
#                 MACD        RSI        ATR        MFI       USDX    VIX  EFFR  \
# Date
# 2006-03-15  4.059285  63.124058  10.392993  56.832217  89.699997  11.35  4.47
# 2006-03-16  4.826013  66.985742  10.051992  56.670295  89.070000  11.98  4.55
# 2006-03-17  5.571365  81.354102   9.988794  60.493283  88.919998  12.12  4.60
# 2006-03-20  6.122679  81.725270   9.984795  60.708410  89.129997  11.79  4.55
# 2006-03-21  6.260491  68.291731  10.033796  60.639310  89.620003  11.62  4.54
#
#             UNRATE  UMSCENT
# Date
# 2006-03-15     4.7     88.9
# 2006-03-16     4.7     88.9
# 2006-03-17     4.7     88.9
# 2006-03-20     4.7     88.9
# 2006-03-21     4.7     88.9

# %%
data.isna().sum()
# Out:
# Open        0
# High        0
# Low         0
# Close       0
# SAR         0
# MACD        0
# RSI         0
# ATR         0
# MFI         0
# USDX        2
# VIX         0
# EFFR       35
# UNRATE      0
# UMSCENT     0
# dtype: int64

# %%
data = data.fillna(data.mean())
data.isna().sum()
# Out:
# Open       0
# High       0
# Low        0
# Close      0
# SAR        0
# MACD       0
# RSI        0
# ATR        0
# MFI        0
# USDX       0
# VIX        0
# EFFR       0
# UNRATE     0
# UMSCENT    0
# dtype: int64

# %%
len(data)
# Out:
# 4397

# %%
output_dir_path = "/content/sample_data/OuputDir"

# %% [markdown]
# ##Data Exploration

# %%
data = data.iloc[:, 3:]
fig = plt.figure(figsize= (10,5))
sns.heatmap(data.corr(), annot=True)
sns.set_style("whitegrid")
plt.show()

# %% [markdown]
# ## Denoising Data

# %%
data.head()
# Out:
#                   Close         SAR      MACD        RSI        ATR  \
# Date
# 2006-03-15  1303.020020  1245.73999  4.059285  63.124058  10.392993
# 2006-03-16  1305.329956  1245.73999  4.826013  66.985742  10.051992
# 2006-03-17  1307.250000  1245.73999  5.571365  81.354102   9.988794
# 2006-03-20  1305.079956  1245.73999  6.122679  81.725270   9.984795
# 2006-03-21  1297.229980  1245.73999  6.260491  68.291731  10.033796
#
#                   MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2006-03-15  56.832217  89.699997  11.35  4.47     4.7     88.9
# 2006-03-16  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2006-03-17  60.493283  88.919998  12.12  4.60     4.7     88.9
# 2006-03-20  60.708410  89.129997  11.79  4.55     4.7     88.9
# 2006-03-21  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
from skimage.restoration import (denoise_wavelet, estimate_sigma)

data['Close']= denoise_wavelet(data.iloc[:, 0], wavelet='haar',
                                      method='VisuShrink',
                                      mode='soft', rescale_sigma = True)
data.head()
# Out:
#                   Close         SAR      MACD        RSI        ATR  \
# Date
# 2006-03-15  1297.479562  1245.73999  4.059285  63.124058  10.392993
# 2006-03-16  1297.479562  1245.73999  4.826013  66.985742  10.051992
# 2006-03-17  1297.479562  1245.73999  5.571365  81.354102   9.988794
# 2006-03-20  1297.479562  1245.73999  6.122679  81.725270   9.984795
# 2006-03-21  1297.479562  1245.73999  6.260491  68.291731  10.033796
#
#                   MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2006-03-15  56.832217  89.699997  11.35  4.47     4.7     88.9
# 2006-03-16  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2006-03-17  60.493283  88.919998  12.12  4.60     4.7     88.9
# 2006-03-20  60.708410  89.129997  11.79  4.55     4.7     88.9
# 2006-03-21  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
data.describe()
# Out:
#              Close          SAR         MACD          RSI          ATR  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean   2216.078954   989.352357     9.961819    55.994301    28.674883
# std    1059.511080   404.539485    36.226028    19.770110    20.503058
# min     728.323895   666.789978  -212.441916     0.000000     8.880007
# 25%    1346.052412   666.789978    -2.658452    42.061798    14.784806
# 50%    1971.031453   666.789978    14.138794    56.496934    20.522988
# 75%    2842.568211  1576.089966    25.995324    70.086803    35.086426
# max    4748.140636  1576.089966   107.397605    99.566735   123.041602
#
#                MFI         USDX          VIX         EFFR       UNRATE  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean     53.891476    88.777090    19.870871     1.299982     6.016352
# std      10.139617     9.272771     9.110330     1.721908     2.205442
# min      22.365246    71.330002     9.140000     0.040000     3.400000
# 25%      46.742932    80.480003    13.740000     0.100000     4.300000
# 50%      53.825806    89.129997    17.500000     0.200000     5.100000
# 75%      61.071333    96.570000    23.110001     1.990000     7.800000
# max      89.979368   114.110001    82.690002     5.410000    14.700000
#
#            UMSCENT
# count  4397.000000
# mean     80.222766
# std      13.047978
# min      50.000000
# 25%      70.600000
# 50%      80.900000
# 75%      91.900000
# max     101.400000

# %% [markdown]
# ##Importing Machine Learning Libraries

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow import keras
from tensorflow.keras import optimizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import time
import math

# %% [markdown]
# ##Supporting Functions

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return (np.mean(np.abs((y_true - y_pred)/(y_true))*100))

def calculate_scores(y_true, y_pred):
  mae = mean_absolute_error(y_true, y_pred)
  mape = mean_absolute_percentage_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mse)
  R = np.corrcoef(y_true, y_pred)
  r2 = r2_score(y_true, y_pred)

  print(f"Mean Absolute Error (MAE): {mae:.4f}")
  print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}")
  print(f"Mean Squared Error (MSE): {mse:.4f}")
  print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
  print(f"R-Pearson Correlation Coefficient (R): {R[0,1]:.4f}")
  print(f"R-squared (R2): {r2:.4f}")
  dic = {'rmse':rmse, 'R': R[0,1], 'mape': mape}
  return (dic)



def DatasetCreation(dataset, time_step = 1): 
   DataX, DataY = [], []
   for i in range(len(dataset)- time_step -1):
         a = dataset[i:(i+ time_step), ]
         DataX.append(a)
         DataY.append(dataset[i + time_step, 0])
   return np.array(DataX), np.array(DataY)


def data_split(data, split = 0.2):
  l1   = int(len(data) * (1- split))
  l2    = len(data) - l1
  data1  = data.iloc[0:l1,:]
  data2   = data.iloc[l1:len(data),:]
  return data1, data2

def min_max_transform(data, feature_range=(0, 1)):
   scaler = MinMaxScaler(feature_range)
   return scaler.fit_transform(data)

def min_max_inverse_transform(data_scaled, min_original, max_original):
    return min_original +  data_scaled*(max_original - min_original)

def write_dic_to_file(dic_name, file_name):
  file = open(file_name, 'w')
  file.write(str(dic_name))
  file.close()

import ast
def read_dic_from_file(file_name):
  file = open(file_name, "r")
  contents = file.read()
  dictionary = ast.literal_eval(contents)
  file.close()
  return dictionary

# %% [markdown]
# ##Supporting Functions for Result Visualization

# %%
def true_pred_plot(model_output):

  y_train = model_output['datasets']['y_train']
  y_test =  model_output['datasets']['y_test']

  train_pred = model_output['best_model']['train_predictions']
  test_pred = model_output['best_model']['test_predictions']

  ##====== Visualizing true vs predicted plots ========#
  fig = plt.figure(figsize= (14,5))
  plt.subplot(121)
  plt.scatter(y_train, train_pred, marker= "+", color = 'mediumblue')
  identity_line = np.linspace(max(min(y_train), min(train_pred)), min(max(y_train), max(train_pred)))
  plt.plot(identity_line, identity_line, color="red", linestyle="dashed", linewidth= 2.5)
  plt.xlabel("True")
  plt.ylabel("Predicted")
  plt.title("Training data (a)")

  plt.subplot(122)
  plt.scatter(y_test, test_pred, marker = "+", color = 'mediumblue')
  identity_line = np.linspace(max(min(y_test), min(test_pred)), min(max(y_test), max(test_pred)))
  plt.plot(identity_line, identity_line, color="red", linestyle="dashed", linewidth= 2.5)
  plt.xlabel("True")
  plt.ylabel("Predicted")
  plt.title("Test data (b)")

  plt.suptitle("Scatter plot of True vs Predicted Close prices")
  plt.show()


def best_model_prediction_plot(model_output):

  time_step =  model_output['hyper_parameters']['time_step']

  data = model_output['datasets']['data']

  train_predict_plot_data = np.empty_like(data.values[:,0])# extracting closing price
  train_predict_plot_data[:] = np.nan

  test_predict_plot_data = np.empty_like(data.values[:,0])
  test_predict_plot_data[:] = np.nan

  fig = plt.figure(figsize = (14,5))

  plt.subplot(121)

  train_pred = model_output['best_model']['train_predictions']
  test_pred = model_output['best_model']['test_predictions']

  train_predict_plot_data[time_step:len(train_pred)+ time_step] =  train_pred
  test_predict_plot_data[len(train_pred)+(time_step*2)+1:len(data.values)-1] = test_pred

  plt.plot(data.values[:,0],'k', linewidth = 1.5)
  plt.plot(train_predict_plot_data,'mediumblue',linewidth = 1.5)
  plt.plot(test_predict_plot_data,'darkgreen',linewidth = 1.5)
  plt.xlabel('')
  plt.ylabel('Close price')
  plt.title("(a)")
  plt.legend(['True value', 'Predicted value in train set', 'Predicted value in test set'], loc = 'upper left')

  plt.subplot(122)
  plt.plot(data.values[len(train_pred)+(time_step*2)+1:-1, 0],'k',linewidth = 1.5)
  plt.plot(test_pred,'darkgreen',linewidth = 1.5)
  plt.xlabel('')
  plt.ylabel('Close price')
  plt.title("(b)")
  plt.legend(['True value', 'Predicted value'], loc='upper left')


def create_visualization(model_output):
  print("==================== Scatter Plot ==========================")
  true_pred_plot(model_output)
  print("==================== Line Plot ==========================")
  best_model_prediction_plot(model_output)

# %% [markdown]
# ## Function for Building Model

# %%
def build_model(layers, time_step, num_features, optimizer = 'Adam', learning_rate = 0.001, verbose = 1):

  model = Sequential()

  for i in range(len(layers)):
    if len(layers)==1:
      model.add(LSTM(int(layers[i]), input_shape = (time_step, num_features)))
    else:
      if i < len(layers)-1:
        if i == 0:
          model.add(LSTM(int(layers[i]), input_shape=(time_step, num_features), return_sequences= True))
          #model.add(Dropout(0.4456))
        else:
          model.add(LSTM(int(layers[i]), return_sequences=True))
          #model.add(Dropout(0.10))
      else:
        model.add(LSTM(int(layers[i])))
        #model.add(Dropout(0.10))
  model.add(Dense(1, activation = 'linear'))

  if optimizer == 'Adam':
    opt = optimizers.Adam(learning_rate = learning_rate)
  elif optimizer == 'Adagrad':
    opt = optimizers.Adagrad(learning_rate = learning_rate)
  elif optimizer == 'Nadam':
    opt = optimizers.Nadam(learning_rate = learning_rate)
  elif optimizer == 'Adadelta':
    opt = optimizers.Adadelta(learning_rate= learning_rate)
  elif optimizer == 'RMSprop':
    opt = optimizers.RMSprop(learning_rate= learning_rate)
  else:
    print("No optimizer found in the list(['Adam', 'Adagrad','Nadam', 'Adadelta', 'RMSprop'])! Please apply your optimizer manually...")

  model.compile(loss='mean_squared_error', optimizer= opt)

  if verbose == 1:
    print(model.summary())
  return model

# %%
optimizers_names = ['Adam', 'Adagrad', 'Nadam']

build_model([250], 5, 10, optimizers_names[2], 0.001, 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 250)               261000
#
#  dense (Dense)               (None, 1)                 251
#
# =================================================================
# Total params: 261251 (1020.51 KB)
# Trainable params: 261251 (1020.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ##Function for Hyperparameter Tuning

# %% [markdown]
# ## Building Multi-Layer LSTM Models

# %%
def multi_layer_LSTM_Model(layers, hyper_parameters, data, time_step = 5, test_split = 0.2, epochs = 5,  num_replicates = 2):
    #====== data transformation==========#
    print("Progress: Performing data preparation steps.......\n")

    #======= creating training and test data===#

    train_data, test_data = data_split(data, test_split)

    num_features = train_data.shape[1]

    min_train, max_train  = train_data["Close"].min(), train_data["Close"].max()
    min_test, max_test   =  test_data["Close"].min(), test_data["Close"].max()

    train_data_scaled  =  min_max_transform(train_data)
    test_data_scaled   = min_max_transform(test_data)


    X_train, y_train  =   DatasetCreation(train_data_scaled, time_step)
    X_test, y_test    =   DatasetCreation(test_data_scaled, time_step)

    y_train_original  =  min_max_inverse_transform(y_train, min_train, max_train) #in original scale
    y_test_original  =  min_max_inverse_transform(y_test, min_test, max_test) #in original scale


    #============ arrays for collecting test scores ================#
    rmse_array = np.zeros(num_replicates)
    mape_array = np.zeros(num_replicates)
    R_array    = np.zeros(num_replicates)
    elapsed_time_array = np.zeros(num_replicates)

    models_history = []
    train_predictions = []
    test_predictions = []

    for i in range(num_replicates):

      print("Program is running for %d replicate ----->\n" %i)

      model = build_model(layers, time_step, num_features, optimizer = hyper_parameters[0], learning_rate = hyper_parameters[1], verbose = 0)
      callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)
      # This callback will stop the training when there is no improvement in
      # the loss for three consecutive epochs
      start = time.time()
      history = model.fit(X_train, y_train, batch_size = hyper_parameters[2], epochs= epochs, callbacks=[callback], verbose = 1)
      end = time.time()
      elapsed_time = end - start

      models_history.append(history)


      #==============Making train and test prediction in original scales ==========
      train_pred   =  min_max_inverse_transform(model.predict(X_train).ravel(), min_train, max_train) #in original scale
      test_pred    =  min_max_inverse_transform(model.predict(X_test).ravel(), min_test, max_test)

      train_predictions.append(train_pred)
      test_predictions.append(test_pred)

      #============== Calculating performance scores==========
      scores =   calculate_scores(min_max_inverse_transform(y_test, min_test, max_test),test_pred)

      rmse_array[i] =  scores['rmse']
      mape_array[i] =  scores['mape']
      R_array[i] = scores['R']
      elapsed_time_array[i] = elapsed_time

    min_index = rmse_array.argmin()
    best_rmse = rmse_array[min_index]
    mape_with_best_rmse = mape_array[min_index]
    R_with_best_rmse =  R_array[min_index]
    elapsed_time_with_best_rmse = elapsed_time_array[min_index]

    train_predictions_with_best_rmse = train_predictions[min_index]
    test_predictions_with_best_rmse = test_predictions[min_index]

    loss_with_best_rmse = models_history[min_index].history['loss']


    #======= Collecting average test scores =============#
    all_scores = {'rmse': rmse_array, 'mape': mape_array, 'R': R_array, 'elapsed_time': elapsed_time_array}

    avg_scores = {'rmse': np.mean(rmse_array),
                  'mape': np.mean(mape_array),
                  'R': np.mean(R_array),
                  'elapsed_time': np.mean(elapsed_time_array)}

    #======= Collecting standard deviations of scores =============#
    stds = {'rmse': np.std(rmse_array),
              'mape': np.std(mape_array),
                  'R': np.std(R_array),
                  'elapsed_time': np.std(elapsed_time_array)}

    #======= Collecting minimum values of test scores =============#
    minimums = {'rmse': np.min(rmse_array),
                'mape': np.min(mape_array),
                'R': np.min(R_array),
                'elapsed_time': np.min(elapsed_time_array)}



    #======= Collecting maximum values of test scores =============#
    maximums = {'rmse': np.max(rmse_array),
                'mape': np.max(mape_array),
                'R': np.max(R_array),
                'elapsed_time': np.max(elapsed_time_array)}


    model_with_best_rmse = {
                            'replicate': min_index,
                            'rmse': best_rmse,
                            'mape': mape_with_best_rmse,
                            'R':  R_with_best_rmse,
                            'elapsed_time': elapsed_time_with_best_rmse,
                            'train_predictions':train_predictions_with_best_rmse,
                            'test_predictions': test_predictions_with_best_rmse,
                            'loss':loss_with_best_rmse,
                         }
     #======= Collecting hyperparameters=============#
    hyper_parameters = {'layers': layers,
                        'model_specific_hyper_parameters': hyper_parameters,#additional best_hyper_parmeters for each models
                       'epochs': epochs,
                       'time_step':time_step,
                       'num_replicates': num_replicates,
                       'test_split':test_split
                        }



    datasets  =   {'data': data,
                  'X_train': X_train,
                  'X_test': X_test,
                  'y_train': y_train_original,
                  'y_test': y_test_original
                  }

    #======= Collecting all the outputs together =============#
    output_dictionary = {'hyper_parameters': hyper_parameters,
                        'best_model': model_with_best_rmse,
                        'all_scores': all_scores,
                        'avg_scores': avg_scores,
                        'standard deviations': stds,
                        'minimums': minimums,
                        'maximums': maximums,
                        'train_predictions': train_predictions,
                        'test_predictions':  test_predictions,
                        'datasets': datasets
                       }

    return output_dictionary

# %%
def run_multi_layer_LSTM_Model(hidden_layers, hyper_parameters, data, time_step = 5, test_split = 0.2, epochs = 5,  num_replicates = 2):

  num_models = len(hidden_layers)

  #== to collect all scores===#
  rmse = []
  mape = []
  R = []
  elapsed_time = []

  #===to collect all avg scores===#
  avg_rmse = []
  avg_mape = []
  avg_R = []
  avg_elapsed_time = []

  #=== to iteratively update the best rmse and the corresponding model
  best_avg_rmse = 99999999999
  best_rmse = 99999999999
  best_model_hidden_layers = None
  best_model_output = None

  for i in range(num_models):
    print("Running model with hidden neurons: ", hidden_layers[i])

    print("\n")

    print("Best Hyper_parameters used: ", hyper_parameters[i])

    print("\n")

    output = multi_layer_LSTM_Model(hidden_layers[i], hyper_parameters[i], data, time_step, test_split, epochs, num_replicates)

    rmse.append(output['all_scores']['rmse'])
    mape.append(output['all_scores']['mape'])
    R.append(output['all_scores']['R'])
    elapsed_time.append(output['all_scores']['elapsed_time'])

    avg_rmse.append(output['avg_scores']['rmse'])
    avg_mape.append(output['avg_scores']['mape'])
    avg_R.append(output['avg_scores']['R'])
    avg_elapsed_time.append(output['avg_scores']['elapsed_time'])

    if avg_rmse[i] < best_avg_rmse:
      best_avg_rmse = avg_rmse[i]
      best_rmse = output['best_model']['rmse']
      best_model_hidden_layers = hidden_layers[i]
      best_model_output = output


  rmse = np.array(rmse)
  mape = np.array(mape)
  R =  np.array(R)

  # ===== Collecting all  scores================================#
  scores = {'layers': hidden_layers, 'rmse': rmse, 'mape': mape, 'R':R, 'elapsed_time': elapsed_time}

  # ======= Collecting avg scores ===============================#
  avg_scores = pd.DataFrame({'layers': hidden_layers, 'rmse': np.array(avg_rmse), 'mape': np.array(avg_mape), 'R':np.array(avg_R), 'elapsed_time':np.array(avg_elapsed_time)})

  #======= Collecting standard deviations of scores =============#
  stds = pd.DataFrame({'layers': hidden_layers, 'rmse': np.std(rmse, axis = 1), 'mape': np.std(mape, axis = 1), 'R':  np.std(R, axis = 1 ),  'elapsed_time': np.std(elapsed_time, axis = 1 )})

  #======= Collecting minimum values of test scores =============#
  minimums = pd.DataFrame({'layers': hidden_layers, 'rmse': np.min(rmse, axis =1 ), 'mape': np.min(mape, axis= 1), 'R': np.min(R, axis =1), 'elapsed_time': np.min(elapsed_time, axis =1)})

  #======= Collecting maximum values of test scores =============#
  maximums = pd.DataFrame({'layers': hidden_layers, 'rmse': np.max(rmse, axis =1), 'mape': np.max(mape, axis =1), 'R': np.max(R, axis =1),  'elapsed_time': np.max(elapsed_time,axis =1)})

  output_dictionary = {
                     'hyper_parameters': hyper_parameters[i],
                     'scores': scores,
                     'avg_scores': avg_scores,
                     'stds':stds,
                     'minimums': minimums,
                     'maximums': maximums,
                      'best_avg_rmse': best_avg_rmse,
                      'best_rmse': best_rmse,
                      'best_model_hidden_layers': best_model_hidden_layers,
                      'best_model_output': best_model_output
                      }


  print("\nBest model and its avg rmse and minimum rmse):\n", best_model_hidden_layers, best_avg_rmse, best_rmse)
  print('\nAverage scores:\n', avg_scores)
  print('\nStandard_deviations:\n', stds)
  print('\nMinimums:\n', minimums)
  print('\nMaximums:\n', maximums)


  #Save all rmse scores in the file for future analysis
  pd.DataFrame(scores['rmse']).to_csv(output_dir_path+'ml-lstm-all-rmse.csv')

  #writing output dictionary in the file
  file_name = output_dir_path + "ml-lstm-results.txt"
  write_dic_to_file(output_dictionary, file_name)

  print("Progress: All works are done successfully, congratulations!!\n")

  return output_dictionary

# %% [markdown]
# # Mulit Layer LSTM

# %%
hidden_layers = [[40, 10], [10, 10, 45]]

best_hyper_parameters_multilayers  = [['Adam', 0.0201, 8],
                                     ['Adam', 0.0115, 9]]

ml_model_output = run_multi_layer_LSTM_Model(hidden_layers, best_hyper_parameters_multilayers, data, time_step = 5, test_split = 0.2, epochs = 100,  num_replicates = 15)
# Out:
# Running model with hidden neurons:  [40, 10]
#
#
# Best Hyper_parameters used:  ['Adam', 0.0201, 8]
#
#
# Progress: Performing data preparation steps.......
#
# Program is running for 0 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 7s 6ms/step - loss: 0.0036
# Epoch 2/100
# 439/439 [==============================] - 3s 7ms/step - loss: 3.3623e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 6ms/step - loss: 4.8936e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.7105e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.0706e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.3732e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3477e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.1483e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9683e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.6382e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.5079e-04
# Epoch 12/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.6219e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 2ms/step
# Mean Absolute Error (MAE): 43.7378
# Mean Absolute Percentage Error (MAPE): 1.1227
# Mean Squared Error (MSE): 3319.8385
# Root Mean Squared Error (RMSE): 57.6180
# R-Pearson Correlation Coefficient (R): 0.9961
# R-squared (R2): 0.9868
# Program is running for 1 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0029
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 7.0430e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 7ms/step - loss: 3.7510e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.0789e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 6ms/step - loss: 3.3620e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.9354e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.6275e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.6287e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.6434e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.6485e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 7ms/step - loss: 9.4389e-05
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9639e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0638e-04
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.8257e-05
# Epoch 15/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.9265e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3297e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 9.6250e-05
# Epoch 18/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.5126e-05
# Epoch 19/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0190e-04
# Epoch 20/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.1435e-04
# Epoch 21/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0140e-04
# Epoch 22/100
# 439/439 [==============================] - 3s 6ms/step - loss: 9.7169e-05
# Epoch 23/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7715e-04
# 110/110 [==============================] - 1s 2ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 46.9119
# Mean Absolute Percentage Error (MAPE): 1.1797
# Mean Squared Error (MSE): 3385.2742
# Root Mean Squared Error (RMSE): 58.1831
# R-Pearson Correlation Coefficient (R): 0.9967
# R-squared (R2): 0.9866
# Program is running for 2 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0032
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.5402e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.8912e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.3278e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 7ms/step - loss: 3.3230e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.3446e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 7ms/step - loss: 3.1254e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8383e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.0496e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5825e-04
# Epoch 11/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.2068e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.0956e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.6497e-04
# Epoch 14/100
# 439/439 [==============================] - 5s 12ms/step - loss: 8.7637e-05
# Epoch 15/100
# 439/439 [==============================] - 4s 9ms/step - loss: 1.8778e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 7.7081e-05
# Epoch 17/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.1205e-04
# Epoch 18/100
# 439/439 [==============================] - 2s 6ms/step - loss: 8.2111e-05
# Epoch 19/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.1011e-04
# Epoch 20/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.1760e-04
# Epoch 21/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.6835e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 89.3570
# Mean Absolute Percentage Error (MAPE): 2.2246
# Mean Squared Error (MSE): 13399.3319
# Root Mean Squared Error (RMSE): 115.7555
# R-Pearson Correlation Coefficient (R): 0.9858
# R-squared (R2): 0.9468
# Program is running for 3 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0027
# Epoch 2/100
# 439/439 [==============================] - 2s 6ms/step - loss: 4.7027e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 6ms/step - loss: 3.8442e-04
# Epoch 4/100
# 439/439 [==============================] - 5s 12ms/step - loss: 3.2185e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 8ms/step - loss: 3.1715e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9771e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.4606e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 7ms/step - loss: 9.2038e-05
# Epoch 9/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9162e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.1586e-04
# Epoch 11/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.3563e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.2218e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0344e-04
# 110/110 [==============================] - 1s 2ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 30.3015
# Mean Absolute Percentage Error (MAPE): 0.7987
# Mean Squared Error (MSE): 1913.9135
# Root Mean Squared Error (RMSE): 43.7483
# R-Pearson Correlation Coefficient (R): 0.9963
# R-squared (R2): 0.9924
# Program is running for 4 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0038
# Epoch 2/100
# 439/439 [==============================] - 3s 7ms/step - loss: 5.7257e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 5.3147e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.0152e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7713e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 5.9848e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7574e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.9038e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.7165e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.1171e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.1134e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7125e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7064e-04
# Epoch 14/100
# 439/439 [==============================] - 2s 6ms/step - loss: 9.3881e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.1646e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.3295e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.9868e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.1239e-04
# Epoch 19/100
# 439/439 [==============================] - 2s 6ms/step - loss: 9.7646e-05
# Epoch 20/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0162e-04
# Epoch 21/100
# 439/439 [==============================] - 3s 7ms/step - loss: 9.8577e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 6ms/step - loss: 8.4887e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 6ms/step - loss: 7.2915e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.4261e-04
# Epoch 25/100
# 439/439 [==============================] - 3s 7ms/step - loss: 9.5493e-05
# Epoch 26/100
# 439/439 [==============================] - 3s 6ms/step - loss: 6.2131e-05
# Epoch 27/100
# 439/439 [==============================] - 3s 6ms/step - loss: 9.9338e-05
# Epoch 28/100
# 439/439 [==============================] - 3s 6ms/step - loss: 7.9830e-05
# Epoch 29/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2196e-04
# Epoch 30/100
# 439/439 [==============================] - 3s 7ms/step - loss: 6.8483e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 6ms/step - loss: 6.8457e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 27.9152
# Mean Absolute Percentage Error (MAPE): 0.7435
# Mean Squared Error (MSE): 1716.1746
# Root Mean Squared Error (RMSE): 41.4267
# R-Pearson Correlation Coefficient (R): 0.9967
# R-squared (R2): 0.9932
# Program is running for 5 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0027
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.2415e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.0255e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.1109e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.4909e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.6835e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.8375e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5447e-04
# Epoch 9/100
# 439/439 [==============================] - 4s 9ms/step - loss: 1.1871e-04
# Epoch 10/100
# 439/439 [==============================] - 4s 9ms/step - loss: 1.1601e-04
# Epoch 11/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.0409e-04
# Epoch 12/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.0852e-04
# Epoch 13/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.6017e-04
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 9.6655e-05
# Epoch 15/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.4190e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.1790e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2634e-04
# Epoch 18/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.2162e-04
# Epoch 19/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.2959e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 61.0022
# Mean Absolute Percentage Error (MAPE): 1.5188
# Mean Squared Error (MSE): 5553.5260
# Root Mean Squared Error (RMSE): 74.5220
# R-Pearson Correlation Coefficient (R): 0.9960
# R-squared (R2): 0.9780
# Program is running for 6 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0029
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 5.3955e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.8118e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 6ms/step - loss: 6.6919e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.7765e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.6245e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7306e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2171e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0031e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.2486e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3421e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.9097e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.6794e-05
# Epoch 14/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.3858e-04
# Epoch 15/100
# 439/439 [==============================] - 3s 6ms/step - loss: 7.7312e-05
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.4521e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.6838e-04
# Epoch 18/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.3539e-04
# Epoch 19/100
# 439/439 [==============================] - 3s 7ms/step - loss: 7.2233e-05
# Epoch 20/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0314e-04
# Epoch 21/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2808e-04
# Epoch 22/100
# 439/439 [==============================] - 3s 6ms/step - loss: 9.8002e-05
# Epoch 23/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.0205e-04
# Epoch 24/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.4409e-04
# 110/110 [==============================] - 1s 2ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 26.1176
# Mean Absolute Percentage Error (MAPE): 0.7139
# Mean Squared Error (MSE): 1871.1823
# Root Mean Squared Error (RMSE): 43.2572
# R-Pearson Correlation Coefficient (R): 0.9963
# R-squared (R2): 0.9926
# Program is running for 7 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0029
# Epoch 2/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.8148e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.3353e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.7830e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.4600e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.5102e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5952e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5423e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.2826e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.1270e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 7ms/step - loss: 4.1840e-04
# Epoch 12/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.0764e-04
# Epoch 13/100
# 439/439 [==============================] - 2s 6ms/step - loss: 9.8492e-05
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.4028e-04
# Epoch 15/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8978e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.0935e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2916e-04
# Epoch 18/100
# 439/439 [==============================] - 2s 6ms/step - loss: 8.3435e-05
# Epoch 19/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9667e-04
# Epoch 20/100
# 439/439 [==============================] - 3s 7ms/step - loss: 8.0342e-05
# Epoch 21/100
# 439/439 [==============================] - 3s 6ms/step - loss: 7.0473e-05
# Epoch 22/100
# 439/439 [==============================] - 3s 7ms/step - loss: 8.3533e-05
# Epoch 23/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.4538e-04
# Epoch 24/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.2478e-05
# Epoch 25/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.0435e-04
# Epoch 26/100
# 439/439 [==============================] - 2s 6ms/step - loss: 9.0629e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 33.5135
# Mean Absolute Percentage Error (MAPE): 0.8703
# Mean Squared Error (MSE): 2351.2957
# Root Mean Squared Error (RMSE): 48.4902
# R-Pearson Correlation Coefficient (R): 0.9957
# R-squared (R2): 0.9907
# Program is running for 8 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 7ms/step - loss: 0.0043
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.8901e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.8330e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.2814e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.5825e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 7ms/step - loss: 3.6477e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.7951e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.1556e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.6278e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5946e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.0021e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8670e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.0893e-04
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.1046e-05
# Epoch 15/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.1343e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.6173e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2591e-04
# Epoch 18/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3638e-04
# Epoch 19/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0879e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 34.7494
# Mean Absolute Percentage Error (MAPE): 0.9128
# Mean Squared Error (MSE): 2527.4193
# Root Mean Squared Error (RMSE): 50.2734
# R-Pearson Correlation Coefficient (R): 0.9954
# R-squared (R2): 0.9900
# Program is running for 9 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0032
# Epoch 2/100
# 439/439 [==============================] - 2s 6ms/step - loss: 5.2034e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.5360e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 8ms/step - loss: 1.6404e-04
# Epoch 5/100
# 439/439 [==============================] - 4s 8ms/step - loss: 1.9300e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 6ms/step - loss: 3.1628e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.4583e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.7695e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.3621e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.5403e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.0855e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8312e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.1974e-05
# Epoch 14/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.7371e-04
# Epoch 15/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5635e-04
# Epoch 16/100
# 439/439 [==============================] - 2s 6ms/step - loss: 1.1795e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2377e-04
# Epoch 18/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.2723e-04
# 110/110 [==============================] - 1s 4ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 31.8354
# Mean Absolute Percentage Error (MAPE): 0.8545
# Mean Squared Error (MSE): 2041.2763
# Root Mean Squared Error (RMSE): 45.1805
# R-Pearson Correlation Coefficient (R): 0.9964
# R-squared (R2): 0.9919
# Program is running for 10 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0028
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.1562e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 3.2473e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 7ms/step - loss: 4.0979e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9031e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3086e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.5793e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 8ms/step - loss: 1.9946e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.6889e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.4881e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9118e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 47.2126
# Mean Absolute Percentage Error (MAPE): 1.2355
# Mean Squared Error (MSE): 3553.9287
# Root Mean Squared Error (RMSE): 59.6148
# R-Pearson Correlation Coefficient (R): 0.9933
# R-squared (R2): 0.9859
# Program is running for 11 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 7s 6ms/step - loss: 0.0034
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 6.3013e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.1140e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.1513e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.1459e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.4157e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.3914e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7647e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.5744e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8858e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9141e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3130e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.6535e-04
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.7071e-04
# Epoch 15/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3469e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.6568e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.3000e-04
# Epoch 18/100
# 439/439 [==============================] - 3s 7ms/step - loss: 6.6991e-05
# Epoch 19/100
# 439/439 [==============================] - 3s 6ms/step - loss: 7.5032e-05
# Epoch 20/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.7565e-05
# Epoch 21/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5180e-04
# Epoch 22/100
# 439/439 [==============================] - 3s 7ms/step - loss: 9.9980e-05
# Epoch 23/100
# 439/439 [==============================] - 3s 7ms/step - loss: 6.5570e-05
# Epoch 24/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5749e-04
# Epoch 25/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.2352e-05
# Epoch 26/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.1005e-04
# Epoch 27/100
# 439/439 [==============================] - 3s 7ms/step - loss: 7.2796e-05
# Epoch 28/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.5060e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 38.7289
# Mean Absolute Percentage Error (MAPE): 0.9876
# Mean Squared Error (MSE): 2814.8637
# Root Mean Squared Error (RMSE): 53.0553
# R-Pearson Correlation Coefficient (R): 0.9959
# R-squared (R2): 0.9888
# Program is running for 12 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0025
# Epoch 2/100
# 439/439 [==============================] - 3s 7ms/step - loss: 4.5734e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.8545e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8973e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.7904e-04
# Epoch 6/100
# 439/439 [==============================] - 4s 8ms/step - loss: 1.4543e-04
# Epoch 7/100
# 439/439 [==============================] - 5s 11ms/step - loss: 2.1952e-04
# Epoch 8/100
# 439/439 [==============================] - 5s 11ms/step - loss: 1.0586e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.0623e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.5367e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.3044e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.4262e-05
# Epoch 13/100
# 439/439 [==============================] - 3s 8ms/step - loss: 2.9317e-04
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.1238e-04
# Epoch 15/100
# 439/439 [==============================] - 3s 6ms/step - loss: 8.4472e-05
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2942e-04
# Epoch 17/100
# 439/439 [==============================] - 3s 6ms/step - loss: 9.2566e-05
# 110/110 [==============================] - 1s 4ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 54.6722
# Mean Absolute Percentage Error (MAPE): 1.3659
# Mean Squared Error (MSE): 4620.7772
# Root Mean Squared Error (RMSE): 67.9763
# R-Pearson Correlation Coefficient (R): 0.9953
# R-squared (R2): 0.9817
# Program is running for 13 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0039
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 7.4596e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.5016e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.2644e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.0774e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.4179e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.6200e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.9945e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8560e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0151e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.8750e-04
# Epoch 12/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.4731e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.4345e-04
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2896e-04
# Epoch 15/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0660e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 38.7363
# Mean Absolute Percentage Error (MAPE): 1.0431
# Mean Squared Error (MSE): 2811.1870
# Root Mean Squared Error (RMSE): 53.0206
# R-Pearson Correlation Coefficient (R): 0.9946
# R-squared (R2): 0.9888
# Program is running for 14 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0040
# Epoch 2/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.4706e-04
# Epoch 3/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.0047e-04
# Epoch 4/100
# 439/439 [==============================] - 3s 7ms/step - loss: 3.5930e-04
# Epoch 5/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.6338e-04
# Epoch 6/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9024e-04
# Epoch 7/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9632e-04
# Epoch 8/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.4372e-04
# Epoch 9/100
# 439/439 [==============================] - 3s 7ms/step - loss: 2.2106e-04
# Epoch 10/100
# 439/439 [==============================] - 3s 6ms/step - loss: 2.9276e-04
# Epoch 11/100
# 439/439 [==============================] - 3s 6ms/step - loss: 9.2405e-05
# Epoch 12/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.0268e-04
# Epoch 13/100
# 439/439 [==============================] - 3s 7ms/step - loss: 1.5438e-04
# Epoch 14/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.9133e-04
# Epoch 15/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.2045e-04
# Epoch 16/100
# 439/439 [==============================] - 3s 6ms/step - loss: 1.5055e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 81.8231
# Mean Absolute Percentage Error (MAPE): 2.0043
# Mean Squared Error (MSE): 9263.3221
# Root Mean Squared Error (RMSE): 96.2462
# R-Pearson Correlation Coefficient (R): 0.9959
# R-squared (R2): 0.9632
# Running model with hidden neurons:  [10, 10, 45]
#
#
# Best Hyper_parameters used:  ['Adam', 0.0115, 9]
#
#
# Progress: Performing data preparation steps.......
#
# Program is running for 0 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 9s 8ms/step - loss: 0.0039
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.9167e-04
# Epoch 3/100
# 391/391 [==============================] - 4s 10ms/step - loss: 4.3501e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.6827e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8104e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.6704e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.4804e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.8381e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.0390e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.1206e-04
# 110/110 [==============================] - 2s 3ms/step
# 28/28 [==============================] - 0s 4ms/step
# Mean Absolute Error (MAE): 69.6578
# Mean Absolute Percentage Error (MAPE): 1.7416
# Mean Squared Error (MSE): 8263.8475
# Root Mean Squared Error (RMSE): 90.9057
# R-Pearson Correlation Coefficient (R): 0.9912
# R-squared (R2): 0.9672
# Program is running for 1 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 7s 8ms/step - loss: 0.0041
# Epoch 2/100
# 391/391 [==============================] - 4s 9ms/step - loss: 7.1146e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.8637e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.0971e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.5021e-04
# Epoch 6/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.5279e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.8953e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.5577e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9761e-04
# Epoch 10/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.9429e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3080e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2014e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8514e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.4537e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.0931e-04
# Epoch 16/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9697e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 81.5627
# Mean Absolute Percentage Error (MAPE): 2.0433
# Mean Squared Error (MSE): 11096.3702
# Root Mean Squared Error (RMSE): 105.3393
# R-Pearson Correlation Coefficient (R): 0.9857
# R-squared (R2): 0.9560
# Program is running for 2 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0041
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.2338e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.5265e-04
# Epoch 4/100
# 391/391 [==============================] - 4s 9ms/step - loss: 5.6042e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.4168e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.2258e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.6880e-04
# Epoch 8/100
# 391/391 [==============================] - 4s 9ms/step - loss: 3.9183e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2841e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9640e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4811e-04
# Epoch 12/100
# 391/391 [==============================] - 4s 9ms/step - loss: 3.2785e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4831e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.1278e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4062e-04
# Epoch 16/100
# 391/391 [==============================] - 5s 12ms/step - loss: 9.2644e-05
# Epoch 17/100
# 391/391 [==============================] - 3s 9ms/step - loss: 9.5243e-05
# Epoch 18/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0280e-04
# Epoch 19/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0924e-04
# Epoch 20/100
# 391/391 [==============================] - 3s 9ms/step - loss: 9.2685e-05
# Epoch 21/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2311e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 63.2810
# Mean Absolute Percentage Error (MAPE): 1.6200
# Mean Squared Error (MSE): 5782.5602
# Root Mean Squared Error (RMSE): 76.0431
# R-Pearson Correlation Coefficient (R): 0.9935
# R-squared (R2): 0.9771
# Program is running for 3 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0043
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 7.3032e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.2428e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 9ms/step - loss: 4.8905e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 7ms/step - loss: 3.4405e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 7ms/step - loss: 2.5259e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.2989e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.0840e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.7431e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3763e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.9867e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.3814e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.1643e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6373e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.7563e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 76.2818
# Mean Absolute Percentage Error (MAPE): 1.9221
# Mean Squared Error (MSE): 8672.4560
# Root Mean Squared Error (RMSE): 93.1260
# R-Pearson Correlation Coefficient (R): 0.9883
# R-squared (R2): 0.9656
# Program is running for 4 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0044
# Epoch 2/100
# 391/391 [==============================] - 3s 9ms/step - loss: 6.6017e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.9322e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.2832e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.7408e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.1378e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3023e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.9839e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.9967e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1894e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.1797e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1911e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.4391e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5659e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6412e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 57.7072
# Mean Absolute Percentage Error (MAPE): 1.5021
# Mean Squared Error (MSE): 5271.9145
# Root Mean Squared Error (RMSE): 72.6080
# R-Pearson Correlation Coefficient (R): 0.9924
# R-squared (R2): 0.9791
# Program is running for 5 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0050
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.6718e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.8532e-04
# Epoch 4/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.7861e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.3902e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.5019e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.0389e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.4207e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3734e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9259e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7191e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.1189e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3536e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2635e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.2216e-04
# Epoch 16/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.8695e-04
# Epoch 17/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2262e-04
# 110/110 [==============================] - 2s 4ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 53.1913
# Mean Absolute Percentage Error (MAPE): 1.3999
# Mean Squared Error (MSE): 4262.3299
# Root Mean Squared Error (RMSE): 65.2865
# R-Pearson Correlation Coefficient (R): 0.9935
# R-squared (R2): 0.9831
# Program is running for 6 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 7s 8ms/step - loss: 0.0050
# Epoch 2/100
# 391/391 [==============================] - 4s 9ms/step - loss: 4.0149e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 6.5606e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.0077e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8150e-04
# Epoch 6/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.5871e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7675e-04
# Epoch 8/100
# 391/391 [==============================] - 4s 10ms/step - loss: 2.5324e-04
# Epoch 9/100
# 391/391 [==============================] - 5s 13ms/step - loss: 2.7450e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8707e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5937e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.1578e-04
# Epoch 13/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.8936e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8956e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7714e-04
# Epoch 16/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7068e-04
# 110/110 [==============================] - 2s 4ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 62.1588
# Mean Absolute Percentage Error (MAPE): 1.5574
# Mean Squared Error (MSE): 5714.1661
# Root Mean Squared Error (RMSE): 75.5921
# R-Pearson Correlation Coefficient (R): 0.9924
# R-squared (R2): 0.9773
# Program is running for 7 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0051
# Epoch 2/100
# 391/391 [==============================] - 4s 9ms/step - loss: 5.4275e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.2916e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.5697e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2150e-04
# Epoch 6/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.8361e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8510e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2581e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2208e-04
# Epoch 10/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6361e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2950e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9042e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5423e-04
# Epoch 14/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5720e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 53.9770
# Mean Absolute Percentage Error (MAPE): 1.3991
# Mean Squared Error (MSE): 4700.4951
# Root Mean Squared Error (RMSE): 68.5602
# R-Pearson Correlation Coefficient (R): 0.9943
# R-squared (R2): 0.9813
# Program is running for 8 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 9s 10ms/step - loss: 0.0034
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 7.9307e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.1260e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.6052e-04
# Epoch 5/100
# 391/391 [==============================] - 4s 10ms/step - loss: 3.4514e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.5775e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6307e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9414e-04
# Epoch 9/100
# 391/391 [==============================] - 4s 10ms/step - loss: 2.1969e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2837e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.8765e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1340e-04
# Epoch 13/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.6828e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 9.5404e-05
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6660e-04
# Epoch 16/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.5187e-04
# Epoch 17/100
# 391/391 [==============================] - 4s 9ms/step - loss: 9.9067e-05
# Epoch 18/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2908e-04
# Epoch 19/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2907e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 53.7087
# Mean Absolute Percentage Error (MAPE): 1.3976
# Mean Squared Error (MSE): 4274.1945
# Root Mean Squared Error (RMSE): 65.3773
# R-Pearson Correlation Coefficient (R): 0.9946
# R-squared (R2): 0.9830
# Program is running for 9 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0036
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 6.9826e-04
# Epoch 3/100
# 391/391 [==============================] - 4s 10ms/step - loss: 5.9823e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.0307e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.4091e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.0460e-04
# Epoch 7/100
# 391/391 [==============================] - 4s 9ms/step - loss: 3.2828e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3069e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9970e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4024e-04
# Epoch 11/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.9787e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6278e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6948e-04
# Epoch 14/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.4060e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.1760e-04
# Epoch 16/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0895e-04
# Epoch 17/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9515e-04
# Epoch 18/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4033e-04
# Epoch 19/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2386e-04
# Epoch 20/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.6045e-04
# Epoch 21/100
# 391/391 [==============================] - 4s 9ms/step - loss: 9.3551e-05
# Epoch 22/100
# 391/391 [==============================] - 5s 12ms/step - loss: 1.0941e-04
# Epoch 23/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4203e-04
# Epoch 24/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0557e-04
# Epoch 25/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0323e-04
# Epoch 26/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4769e-04
# 110/110 [==============================] - 1s 4ms/step
# 28/28 [==============================] - 0s 5ms/step
# Mean Absolute Error (MAE): 140.3120
# Mean Absolute Percentage Error (MAPE): 3.4734
# Mean Squared Error (MSE): 24478.7424
# Root Mean Squared Error (RMSE): 156.4568
# R-Pearson Correlation Coefficient (R): 0.9936
# R-squared (R2): 0.9028
# Program is running for 10 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0079
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.6289e-04
# Epoch 3/100
# 391/391 [==============================] - 4s 9ms/step - loss: 4.1731e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.6592e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.1349e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.8285e-04
# Epoch 7/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.5316e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.9535e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5220e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 9ms/step - loss: 3.2264e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.0576e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9183e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1326e-04
# Epoch 14/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3582e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0033e-04
# Epoch 16/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0345e-04
# Epoch 17/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2544e-04
# Epoch 18/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5915e-04
# Epoch 19/100
# 391/391 [==============================] - 3s 8ms/step - loss: 9.6593e-05
# Epoch 20/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3139e-04
# Epoch 21/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2311e-04
# Epoch 22/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.7195e-04
# Epoch 23/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0462e-04
# Epoch 24/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0895e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 33.2868
# Mean Absolute Percentage Error (MAPE): 0.8932
# Mean Squared Error (MSE): 2345.7046
# Root Mean Squared Error (RMSE): 48.4325
# R-Pearson Correlation Coefficient (R): 0.9959
# R-squared (R2): 0.9907
# Program is running for 11 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 9s 10ms/step - loss: 0.0041
# Epoch 2/100
# 391/391 [==============================] - 6s 15ms/step - loss: 9.2411e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 9ms/step - loss: 4.7137e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 5.1930e-04
# Epoch 5/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2185e-04
# Epoch 6/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.0810e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.5664e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.0448e-04
# Epoch 9/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1102e-04
# Epoch 10/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.8361e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.0243e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7758e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3871e-04
# Epoch 14/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.9012e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 73.2546
# Mean Absolute Percentage Error (MAPE): 1.8843
# Mean Squared Error (MSE): 8125.1538
# Root Mean Squared Error (RMSE): 90.1396
# R-Pearson Correlation Coefficient (R): 0.9853
# R-squared (R2): 0.9678
# Program is running for 12 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 8s 8ms/step - loss: 0.0051
# Epoch 2/100
# 391/391 [==============================] - 4s 10ms/step - loss: 7.7203e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.7320e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.4234e-04
# Epoch 5/100
# 391/391 [==============================] - 4s 10ms/step - loss: 3.8444e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.5522e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.0128e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9042e-04
# Epoch 9/100
# 391/391 [==============================] - 4s 10ms/step - loss: 2.8309e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8720e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7684e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7333e-04
# Epoch 13/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.3778e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5437e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8522e-04
# Epoch 16/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4101e-04
# Epoch 17/100
# 391/391 [==============================] - 4s 10ms/step - loss: 8.0948e-05
# Epoch 18/100
# 391/391 [==============================] - 3s 9ms/step - loss: 8.1532e-05
# Epoch 19/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.2558e-04
# Epoch 20/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.2229e-04
# Epoch 21/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4028e-04
# Epoch 22/100
# 391/391 [==============================] - 3s 8ms/step - loss: 7.7825e-05
# Epoch 23/100
# 391/391 [==============================] - 3s 8ms/step - loss: 9.6055e-05
# Epoch 24/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.1582e-04
# Epoch 25/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2319e-04
# Epoch 26/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8793e-04
# Epoch 27/100
# 391/391 [==============================] - 4s 9ms/step - loss: 9.9304e-05
# 110/110 [==============================] - 2s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 39.4646
# Mean Absolute Percentage Error (MAPE): 1.0159
# Mean Squared Error (MSE): 2763.8813
# Root Mean Squared Error (RMSE): 52.5726
# R-Pearson Correlation Coefficient (R): 0.9945
# R-squared (R2): 0.9890
# Program is running for 13 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 9s 9ms/step - loss: 0.0064
# Epoch 2/100
# 391/391 [==============================] - 4s 9ms/step - loss: 6.4729e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.7343e-04
# Epoch 4/100
# 391/391 [==============================] - 3s 8ms/step - loss: 4.7290e-04
# Epoch 5/100
# 391/391 [==============================] - 4s 9ms/step - loss: 3.7920e-04
# Epoch 6/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3526e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.2012e-04
# Epoch 8/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.7756e-04
# Epoch 9/100
# 391/391 [==============================] - 4s 10ms/step - loss: 2.2780e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.1258e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8669e-04
# Epoch 12/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.1377e-04
# Epoch 13/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.8284e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.4986e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2187e-04
# Epoch 16/100
# 391/391 [==============================] - 4s 10ms/step - loss: 2.8848e-04
# Epoch 17/100
# 391/391 [==============================] - 4s 9ms/step - loss: 3.4489e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 4ms/step
# Mean Absolute Error (MAE): 64.1165
# Mean Absolute Percentage Error (MAPE): 1.6575
# Mean Squared Error (MSE): 6527.1219
# Root Mean Squared Error (RMSE): 80.7906
# R-Pearson Correlation Coefficient (R): 0.9890
# R-squared (R2): 0.9741
# Program is running for 14 replicate ----->
#
# Epoch 1/100
# 391/391 [==============================] - 9s 10ms/step - loss: 0.0071
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 6.2336e-04
# Epoch 3/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.6775e-04
# Epoch 4/100
# 391/391 [==============================] - 4s 9ms/step - loss: 4.8717e-04
# Epoch 5/100
# 391/391 [==============================] - 4s 10ms/step - loss: 2.8866e-04
# Epoch 6/100
# 391/391 [==============================] - 3s 8ms/step - loss: 3.4834e-04
# Epoch 7/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9886e-04
# Epoch 8/100
# 391/391 [==============================] - 4s 9ms/step - loss: 2.5711e-04
# Epoch 9/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.5485e-04
# Epoch 10/100
# 391/391 [==============================] - 3s 9ms/step - loss: 2.0971e-04
# Epoch 11/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.0887e-04
# Epoch 12/100
# 391/391 [==============================] - 4s 10ms/step - loss: 2.4620e-04
# Epoch 13/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1384e-04
# Epoch 14/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7217e-04
# Epoch 15/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3224e-04
# Epoch 16/100
# 391/391 [==============================] - 4s 10ms/step - loss: 1.1489e-04
# Epoch 17/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2440e-04
# Epoch 18/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7135e-04
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 30.0837
# Mean Absolute Percentage Error (MAPE): 0.8247
# Mean Squared Error (MSE): 2429.6781
# Root Mean Squared Error (RMSE): 49.2918
# R-Pearson Correlation Coefficient (R): 0.9955
# R-squared (R2): 0.9904
#
# Best model and its avg rmse and minimum rmse):
#  [40, 10] 60.557874142030826 41.42673737189747
#
# Average scores:
#           layers       rmse      mape         R  elapsed_time
# 0      [40, 10]  60.557874  1.171723  0.995094     57.112872
# 1  [10, 10, 45]  79.368146  1.622122  0.991983     64.420366
#
# Standard_deviations:
#           layers       rmse      mape         R  elapsed_time
# 0      [40, 10]  20.222873  0.432618  0.002630     14.910948
# 1  [10, 10, 45]  26.101184  0.604521  0.003282     15.762815
#
# Minimums:
#           layers       rmse      mape         R  elapsed_time
# 0      [40, 10]  41.426737  0.713854  0.985769     33.121712
# 1  [10, 10, 45]  48.432474  0.824741  0.985286     38.689377
#
# Maximums:
#           layers        rmse      mape         R  elapsed_time
# 0      [40, 10]  115.755483  2.224551  0.996700     84.954244
# 1  [10, 10, 45]  156.456839  3.473396  0.995935     97.586872
# Progress: All works are done successfully, congratulations!!
